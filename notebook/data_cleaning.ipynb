# %% [markdown]
# DATA CLEANING

# %%
import pandas as pd
import sys
import os

# %%
# Append the project root path to sys.path
sys.path.append(os.path.abspath(".."))

# %% [markdown]
# IMPORTING MODULES FOR CLEANING DATA

# %%
from src.data_cleaning import load_csv, clean_dataframe, save_cleaned_data

# %% [markdown]
# Data Loading into dataframe

# %%
df=pd.read_csv("C:\\Users\\lenovo\\OneDrive\\Desktop\\10Academy Files\\week7_project\\Kara_solution-1\\data\\telegram\\telegram_data.csv")

# %% [markdown]
# DATA CLEANING PROCESS AND SAMPLE OUTPUT

# %%
data_cleaned=clean_dataframe(df)
data_cleaned.head(10)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 60, in clean_dataframe
#     logging.info("✅ Duplicates removed from dataset.")
# Message: '✅ Duplicates removed from dataset.'
# Arguments: ()
# 2025-01-31 21:27:06,743 - INFO - ✅ Duplicates removed from dataset.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 65, in clean_dataframe
#     logging.info("✅ Date column formatted to datetime.")
# Message: '✅ Date column formatted to datetime.'
# Arguments: ()
# 2025-01-31 21:27:06,802 - INFO - ✅ Date column formatted to datetime.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 73, in clean_dataframe
#     logging.info("✅ Missing values filled.")
# Message: '✅ Missing values filled.'
# Arguments: ()
# 2025-01-31 21:27:06,815 - INFO - ✅ Missing values filled.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 80, in clean_dataframe
#     logging.info("✅ Text columns standardized.")
# Message: '✅ Text columns standardized.'
# Arguments: ()
# 2025-01-31 21:27:06,936 - INFO - ✅ Text columns standardized.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 84, in clean_dataframe
#     logging.info("✅ Emojis extracted and stored in 'emoji_used' column.")
# Message: "✅ Emojis extracted and stored in 'emoji_used' column."
# Arguments: ()
# 2025-01-31 21:27:07,252 - INFO - ✅ Emojis extracted and stored in 'emoji_used' column.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 91, in clean_dataframe
#     logging.info("✅ YouTube links extracted and stored in 'youtube_links' column.")
# Message: "✅ YouTube links extracted and stored in 'youtube_links' column."
# Arguments: ()
# 2025-01-31 21:27:07,682 - INFO - ✅ YouTube links extracted and stored in 'youtube_links' column.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\4010607787.py", line 1, in <module>
#     data_cleaned=clean_dataframe(df)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 108, in clean_dataframe
#     logging.info("✅ Data cleaning completed successfully.")
# Message: '✅ Data cleaning completed successfully.'
# Arguments: ()
# 2025-01-31 21:27:07,704 - INFO - ✅ Data cleaning completed successfully.
#                                        channel_title channel_username  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 5  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 6  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 7  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 8  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
# 9  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...           @EAHCI
#
#    message_id                                            message  \
# 0        2602  #ENGLISH_LANGUAGE_TRAINING Grammar Vocabulary ...
# 1        2601  Congratulations to our beloved trainees on com...
# 2        2600  #የግርዛት_ስልጠና_Addis_Ababa  #Circumcision_Skill_T...
# 3        2598  #CPD_አሁን_ይመዝገቡ #የሞያ_ፈቃድ_ለማሳደስ_CPD_ይመዝገቡ #Title...
# 4        2597  #OBGYN_Ultrasound_Training@Hawassa! #ጥር_25/201...
# 5        2596                                         No Message
# 6        2595  #Adult_ECHO_Training@#ADISS_ABABA_By_Cardiolog...
# 7        2594                                         No Message
# 8        2593  #ነገ_ይጀምራል_Ultrasound_ስልጠና_አዲስ_አበባ_ጋንዲ_ሆስፒታል  #...
# 9        2592                                         No Message
#
#                 message_date media_path            emoji_used    youtube_links
# 0  2025-01-30 12:17:14+00:00   No Media                👉👉👉📌📞📞  No YouTube link
# 1  2025-01-30 09:57:21+00:00   No Media                    🎉🎊  No YouTube link
# 2  2025-01-29 17:00:02+00:00   No Media  🔶🔶🔶🔶🔶🔶🔶🔶🔶🔶👉👉📞📞📞📞📞📞👉👉  No YouTube link
# 3  2025-01-29 12:34:11+00:00   No Media           💥🔶👉📱📱📱📱📱📳🏃❗  No YouTube link
# 4  2025-01-27 11:01:51+00:00   No Media              ✔💥☎☎☎☎☎🏃  No YouTube link
# 5  2025-01-26 13:17:46+00:00   No Media              No emoji  No YouTube link
# 6  2025-01-26 13:17:40+00:00   No Media                  👉👉📞📞  No YouTube link
# 7  2025-01-25 08:37:18+00:00   No Media              No emoji  No YouTube link
# 8  2025-01-24 14:09:14+00:00   No Media               ✔☎☎☎☎☎🏃  No YouTube link
# 9  2025-01-24 08:49:19+00:00   No Media              No emoji  No YouTube link

# %% [markdown]
# CHECK AND REPLACE MISSING VALUE IN CLEANED DATAFRAME

# %%
missing_value=data_cleaned.isnull().sum()
missing_value
# Out:
# channel_title       0
# channel_username    0
# message_id          0
# message             0
# message_date        0
# media_path          0
# emoji_used          0
# youtube_links       0
# dtype: int64

# %% [markdown]
# save cleaned data to the given path

# %%
save_cleaned_data(data_cleaned, "C:\\Users\\lenovo\\OneDrive\\Desktop\\10Academy Files\\week7_project\\Kara_solution-1\\cleaned_telegram_data.csv")
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\1359888499.py", line 1, in <module>
#     save_cleaned_data(data_cleaned, "C:\\Users\\lenovo\\OneDrive\\Desktop\\10Academy Files\\week7_project\\Kara_solution-1\\cleaned_telegram_data.csv")
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\data_cleaning.py", line 118, in save_cleaned_data
#     logging.info(f"✅ Cleaned data saved successfully to '{output_path}'.")
# Message: "✅ Cleaned data saved successfully to 'C:\\Users\\lenovo\\OneDrive\\Desktop\\10Academy Files\\week7_project\\Kara_solution-1\\cleaned_telegram_data.csv'."
# Arguments: ()
# 2025-01-31 21:27:07,977 - INFO - ✅ Cleaned data saved successfully to 'C:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\cleaned_telegram_data.csv'.
# ✅ Cleaned data saved successfully to 'C:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\cleaned_telegram_data.csv'.

# %% [markdown]
# # DATABASE CONNECTION

# %%
from src.db_connection import get_db_connection, create_engine, create_table, insert_data

# %%
engine=get_db_connection()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2705' in position 33: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\452513916.py", line 1, in <module>
#     engine=get_db_connection()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\db_connection.py", line 34, in get_db_connection
#     logging.info("✅ Successfully connected to the PostgreSQL database.")
# Message: '✅ Successfully connected to the PostgreSQL database.'
# Arguments: ()
# 2025-01-31 21:29:46,653 - INFO - ✅ Successfully connected to the PostgreSQL database.

# %%
insert_data(engine,data_cleaned)
# Out:
# 2025-01-31 21:29:52,708 - INFO - Inserting: 2602 - 2025-01-30 12:17:14+00:00
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1964, in _exec_single_context
#     self.dialect.do_execute(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         cursor, str_statement, effective_parameters, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\default.py", line 942, in do_execute
#     cursor.execute(statement, parameters)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
# psycopg2.errors.UndefinedTable: relation "telegram_messages" does not exist
# LINE 2:         INSERT INTO telegram_messages
#                             ^
#
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\db_connection.py", line 83, in insert_data
#     connection.execute(
#     ~~~~~~~~~~~~~~~~~~^
#         text(insert_query),
#         ^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#         }
#         ^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1416, in execute
#     return meth(
#         self,
#         distilled_parameters,
#         execution_options or NO_OPTIONS,
#     )
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\sql\elements.py", line 515, in _execute_on_connection
#     return connection._execute_clauseelement(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self, distilled_params, execution_options
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1638, in _execute_clauseelement
#     ret = self._execute_context(
#         dialect,
#     ...<8 lines>...
#         cache_hit=cache_hit,
#     )
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1843, in _execute_context
#     return self._exec_single_context(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^
#         dialect, context, statement, parameters
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1983, in _exec_single_context
#     self._handle_dbapi_exception(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         e, str_statement, effective_parameters, cursor, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 2352, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py", line 1964, in _exec_single_context
#     self.dialect.do_execute(
#     ~~~~~~~~~~~~~~~~~~~~~~~^
#         cursor, str_statement, effective_parameters, context
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\default.py", line 942, in do_execute
#     cursor.execute(statement, parameters)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
# sqlalchemy.exc.ProgrammingError: (psycopg2.errors.UndefinedTable) relation "telegram_messages" does not exist
# LINE 2:         INSERT INTO telegram_messages
#                             ^
#
# [SQL:
#         INSERT INTO telegram_messages
#         (channel_title, channel_username, message_id, message, message_date, media_path, emoji_used, youtube_links)
#         VALUES (%(channel_title)s, %(channel_username)s, %(message_id)s, %(message)s, %(message_date)s, %(media_path)s, %(emoji_used)s, %(youtube_links)s)
#         ON CONFLICT (message_id) DO NOTHING;
#         ]
# [parameters: {'channel_title': 'ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEALTH CONSULTANCY CENTER', 'channel_username': '@EAHCI', 'message_id': 2602, 'message': '#ENGLISH_LANGUAGE_TRAINING Grammar Vocabulary  Pronunciation   Strarting from #March_3_የካቲት_24 ይጀምራል! #HAWASSA Contact us and register now! 0965412222 0941404444 ETHIO-AMERICAN TRAINING CENTER!', 'message_date': '2025-01-30 12:17:14+00:00', 'media_path': 'No Media', 'emoji_used': '👉👉👉📌📞📞', 'youtube_links': 'No YouTube link'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py", line 1153, in emit
#     stream.write(msg + self.terminator)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'charmap' codec can't encode character '\u274c' in position 34: character maps to <undefined>
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 679, in run_forever
#     self._run_once()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py", line 2027, in _run_once
#     handle._run()
#   File "C:\Users\lenovo\AppData\Local\Programs\Python\Python313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\lenovo\AppData\Local\Temp\ipykernel_3840\149696951.py", line 1, in <module>
#     insert_data(engine,data_cleaned)
#   File "c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\db_connection.py", line 99, in insert_data
#     logging.error(f"❌ Error inserting data: {e}")
# Message: '❌ Error inserting data: (psycopg2.errors.UndefinedTable) relation "telegram_messages" does not exist\nLINE 2:         INSERT INTO telegram_messages \n                            ^\n\n[SQL: \n        INSERT INTO telegram_messages \n        (channel_title, channel_username, message_id, message, message_date, media_path, emoji_used, youtube_links) \n        VALUES (%(channel_title)s, %(channel_username)s, %(message_id)s, %(message)s, %(message_date)s, %(media_path)s, %(emoji_used)s, %(youtube_links)s)\n        ON CONFLICT (message_id) DO NOTHING;\n        ]\n[parameters: {\'channel_title\': \'ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEALTH CONSULTANCY CENTER\', \'channel_username\': \'@EAHCI\', \'message_id\': 2602, \'message\': \'#ENGLISH_LANGUAGE_TRAINING Grammar Vocabulary  Pronunciation   Strarting from #March_3_የካቲት_24 ይጀምራል! #HAWASSA Contact us and register now! 0965412222 0941404444 ETHIO-AMERICAN TRAINING CENTER!\', \'message_date\': \'2025-01-30 12:17:14+00:00\', \'media_path\': \'No Media\', \'emoji_used\': \'👉👉👉📌📞📞\', \'youtube_links\': \'No YouTube link\'}]\n(Background on this error at: https://sqlalche.me/e/20/f405)'
# Arguments: ()
# 2025-01-31 21:29:52,718 - ERROR - ❌ Error inserting data: (psycopg2.errors.UndefinedTable) relation "telegram_messages" does not exist
# LINE 2:         INSERT INTO telegram_messages
#                             ^
#
# [SQL:
#         INSERT INTO telegram_messages
#         (channel_title, channel_username, message_id, message, message_date, media_path, emoji_used, youtube_links)
#         VALUES (%(channel_title)s, %(channel_username)s, %(message_id)s, %(message)s, %(message_date)s, %(media_path)s, %(emoji_used)s, %(youtube_links)s)
#         ON CONFLICT (message_id) DO NOTHING;
#         ]
# [parameters: {'channel_title': 'ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEALTH CONSULTANCY CENTER', 'channel_username': '@EAHCI', 'message_id': 2602, 'message': '#ENGLISH_LANGUAGE_TRAINING Grammar Vocabulary  Pronunciation   Strarting from #March_3_የካቲት_24 ይጀምራል! #HAWASSA Contact us and register now! 0965412222 0941404444 ETHIO-AMERICAN TRAINING CENTER!', 'message_date': '2025-01-30 12:17:14+00:00', 'media_path': 'No Media', 'emoji_used': '👉👉👉📌📞📞', 'youtube_links': 'No YouTube link'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "telegram_messages" does not exist
# LINE 2:         INSERT INTO telegram_messages
#                             ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 insert_data(engine,data_cleaned)
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\src\db_connection.py:83, in insert_data(engine, cleaned_df)
#      79         for _, row in cleaned_df.iterrows():
#      80             # Debug log to ensure data is being inserted
#      81             logging.info(f"Inserting: {row['message_id']} - {row['message_date']}")
# ---> 83             connection.execute(
#      84                 text(insert_query),
#      85                 {
#      86                     "channel_title": row["channel_title"],
#      87                     "channel_username": row["channel_username"],
#      88                     "message_id": row["message_id"],
#      89                     "message": row["message"],
#      90                     "message_date": row["message_date"],  # ✅ No NaT values
#      91                     "media_path": row["media_path"],
#      92                     "emoji_used": row["emoji_used"],
#      93                     "youtube_links": row["youtube_links"]
#      94                 }
#      95             )
#      97     logging.info(f"✅ {len(cleaned_df)} records inserted into PostgreSQL database.")
#      98 except Exception as e:
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1416, in Connection.execute(self, statement, parameters, execution_options)
#    1414     raise exc.ObjectNotExecutableError(statement) from err
#    1415 else:
# -> 1416     return meth(
#    1417         self,
#    1418         distilled_parameters,
#    1419         execution_options or NO_OPTIONS,
#    1420     )
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1638, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1626 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1627     "compiled_cache", self.engine._compiled_cache
#    1628 )
#    1630 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1631     dialect=dialect,
#    1632     compiled_cache=compiled_cache,
#    (...)
#    1636     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1637 )
# -> 1638 ret = self._execute_context(
#    1639     dialect,
#    1640     dialect.execution_ctx_cls._init_compiled,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     execution_options,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     elem,
#    1647     extracted_params,
#    1648     cache_hit=cache_hit,
#    1649 )
#    1650 if has_events:
#    1651     self.dispatch.after_execute(
#    1652         self,
#    1653         elem,
#    (...)
#    1657         ret,
#    1658     )
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)
#    1975         context.executemany,
#    1976     )
#
# File c:\Users\lenovo\OneDrive\Desktop\10Academy Files\week7_project\Kara_solution-1\week7\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "telegram_messages" does not exist
# LINE 2:         INSERT INTO telegram_messages
#                             ^
#
# [SQL:
#         INSERT INTO telegram_messages
#         (channel_title, channel_username, message_id, message, message_date, media_path, emoji_used, youtube_links)
#         VALUES (%(channel_title)s, %(channel_username)s, %(message_id)s, %(message)s, %(message_date)s, %(media_path)s, %(emoji_used)s, %(youtube_links)s)
#         ON CONFLICT (message_id) DO NOTHING;
#         ]
# [parameters: {'channel_title': 'ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEALTH CONSULTANCY CENTER', 'channel_username': '@EAHCI', 'message_id': 2602, 'message': '#ENGLISH_LANGUAGE_TRAINING Grammar Vocabulary  Pronunciation   Strarting from #March_3_የካቲት_24 ይጀምራል! #HAWASSA Contact us and register now! 0965412222 0941404444 ETHIO-AMERICAN TRAINING CENTER!', 'message_date': '2025-01-30 12:17:14+00:00', 'media_path': 'No Media', 'emoji_used': '👉👉👉📌📞📞', 'youtube_links': 'No YouTube link'}]
# (Background on this error at: https://sqlalche.me/e/20/f405)
